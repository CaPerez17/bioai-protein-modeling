# %% [markdown]
# # Day 1: FASTA Basics
#
# Learning to work with FASTA protein sequences.

# %% [markdown]
# ## Imports

# %%
# TODO: Add imports here

# %% [markdown]
# ## Experiments

# %%
# TODO: Add experiments here
